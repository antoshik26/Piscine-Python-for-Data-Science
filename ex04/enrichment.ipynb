# %%
import pandas as pd
import numpy as np
import requests

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_json('/content/drive/MyDrive/auto.json', orient='CarNumber')
df
# Out:
#         CarNumber    Make_n_model  Refund         Fines    Make    Model
# 0    Y163O8161RUS      Ford Focus       2   3200.000000    Ford    Focus
# 1     E432XX77RUS    Toyota Camry       1   6500.000000  Toyota    Camry
# 2     7184TT36RUS      Ford Focus       1   2100.000000    Ford    Focus
# 3    X582HE161RUS      Ford Focus       2   2000.000000    Ford    Focus
# 4    92918M178RUS      Ford Focus       1   5700.000000    Ford    Focus
# ..            ...             ...     ...           ...     ...      ...
# 720  Y163O8161RUS      Ford Focus       2   1600.000000    Ford    Focus
# 721  M0309X197RUS      Ford Focus       1  22300.000000    Ford    Focus
# 722  O673E8197RUS      Ford Focus       2    600.000000    Ford    Focus
# 723  8610T8154RUS      Ford Focus       1   2000.000000    Ford    Focus
# 724  H419XE197RUS  Toyota Corolla       2   8594.586466  Toyota  Corolla
#
# [725 rows x 6 columns]

# %%
df = df.set_index(df.CarNumber)
df = df.drop('CarNumber', axis=1)
df
# Out:
#                 Make_n_model  Refund         Fines    Make    Model
# CarNumber
# Y163O8161RUS      Ford Focus       2   3200.000000    Ford    Focus
# E432XX77RUS     Toyota Camry       1   6500.000000  Toyota    Camry
# 7184TT36RUS       Ford Focus       1   2100.000000    Ford    Focus
# X582HE161RUS      Ford Focus       2   2000.000000    Ford    Focus
# 92918M178RUS      Ford Focus       1   5700.000000    Ford    Focus
# ...                      ...     ...           ...     ...      ...
# Y163O8161RUS      Ford Focus       2   1600.000000    Ford    Focus
# M0309X197RUS      Ford Focus       1  22300.000000    Ford    Focus
# O673E8197RUS      Ford Focus       2    600.000000    Ford    Focus
# 8610T8154RUS      Ford Focus       1   2000.000000    Ford    Focus
# H419XE197RUS  Toyota Corolla       2   8594.586466  Toyota  Corolla
#
# [725 rows x 5 columns]

# %%
 df['Refund'] = df['Refund'].map('{:,.2f}'.format)
 df
# Out:
#         CarNumber    Make_n_model Refund         Fines    Make    Model
# 0    Y163O8161RUS      Ford Focus   2.00   3200.000000    Ford    Focus
# 1     E432XX77RUS    Toyota Camry   1.00   6500.000000  Toyota    Camry
# 2     7184TT36RUS      Ford Focus   1.00   2100.000000    Ford    Focus
# 3    X582HE161RUS      Ford Focus   2.00   2000.000000    Ford    Focus
# 4    92918M178RUS      Ford Focus   1.00   5700.000000    Ford    Focus
# ..            ...             ...    ...           ...     ...      ...
# 720  Y163O8161RUS      Ford Focus   2.00   1600.000000    Ford    Focus
# 721  M0309X197RUS      Ford Focus   1.00  22300.000000    Ford    Focus
# 722  O673E8197RUS      Ford Focus   2.00    600.000000    Ford    Focus
# 723  8610T8154RUS      Ford Focus   1.00   2000.000000    Ford    Focus
# 724  H419XE197RUS  Toyota Corolla   2.00   8594.586466  Toyota  Corolla
#
# [725 rows x 6 columns]

# %%
df = df.drop('Make_n_model', axis=1)
np.random.seed(21)
df
# Out:
#         CarNumber Refund         Fines    Make    Model
# 0    Y163O8161RUS   2.00   3200.000000    Ford    Focus
# 1     E432XX77RUS   1.00   6500.000000  Toyota    Camry
# 2     7184TT36RUS   1.00   2100.000000    Ford    Focus
# 3    X582HE161RUS   2.00   2000.000000    Ford    Focus
# 4    92918M178RUS   1.00   5700.000000    Ford    Focus
# ..            ...    ...           ...     ...      ...
# 720  Y163O8161RUS   2.00   1600.000000    Ford    Focus
# 721  M0309X197RUS   1.00  22300.000000    Ford    Focus
# 722  O673E8197RUS   2.00    600.000000    Ford    Focus
# 723  8610T8154RUS   1.00   2000.000000    Ford    Focus
# 724  H419XE197RUS   2.00   8594.586466  Toyota  Corolla
#
# [725 rows x 5 columns]

# %%
df2 = pd.DataFrame()
df2['CarNumber'] = []
df2['Refund'] = []
df2['Fines'] = []
df2['Make'] = []
df2['Model'] = []
# df = df.set_index(df.CarNumber)
# df = df.drop('CarNumber', axis=1)
index = []
df_arr = []
for i in range(0,200):
  index.append(np.random.randint(725))
for i in index:
  a = (df.iloc[df.index[i]])
  df_arr.append([a.CarNumber, a.Refund, a.Fines, a.Make, a.Model])
df3 = pd.concat([pd.DataFrame(df_arr, columns=["CarNumber", "Refund","Fines", "Make","Model"])], axis=1)
df3
# Out:
#         CarNumber Refund    Fines   Make    Model
# 0    705387163RUS   2.00    700.0   Ford    Focus
# 1     9502XX38RUS   1.00   3000.0  Skoda  Octavia
# 2    7831C8197RUS   2.00   3400.0   Ford    Focus
# 3    9943KK197RUS   2.00  19800.0   Ford    Focus
# 4    E881OT197RUS   2.00   5500.0  Skoda  Octavia
# ..            ...    ...      ...    ...      ...
# 195  82337X197RUS   2.00   2100.0   Ford    Focus
# 196  H967HY161RUS   2.00   4500.0   Ford    Focus
# 197  8441XX154RUS   1.00    500.0   Ford    Focus
# 198  Y359EY197RUS   2.00   3000.0  Skoda  Octavia
# 199  E79988152RUS   1.00    500.0   Ford    Focus
#
# [200 rows x 5 columns]

# %%
concat_rows = pd.concat([df, df3])
df4 = concat_rows

# %%
df4['Year'] = pd.Series([np.random.randint(1980, 2020) for i in range(1025)])

# %%
df4
# Out:
#         CarNumber Refund   Fines    Make    Model  Year
# 0    Y163O8161RUS   2.00  3200.0    Ford    Focus  1982
# 1     E432XX77RUS   1.00  6500.0  Toyota    Camry  1999
# 2     7184TT36RUS   1.00  2100.0    Ford    Focus  2004
# 3    X582HE161RUS   2.00  2000.0    Ford    Focus  1984
# 4    92918M178RUS   1.00  5700.0    Ford    Focus  1993
# ..            ...    ...     ...     ...      ...   ...
# 195  82337X197RUS   2.00  2100.0    Ford    Focus  2017
# 196  H967HY161RUS   2.00  4500.0    Ford    Focus  1992
# 197  8441XX154RUS   1.00   500.0    Ford    Focus  2018
# 198  Y359EY197RUS   2.00  3000.0   Skoda  Octavia  2003
# 199  E79988152RUS   1.00   500.0    Ford    Focus  2010
#
# [925 rows x 6 columns]

# %%
url = 'https://api.census.gov/data/2010/surname?get=NAME,COUNT&RANK=1:100'
chars = '""[],0123456789'
page = requests.get(url).text
surnames = [line.strip(chars).capitalize() for line in page.split('\n')]

# %%
owners = pd.DataFrame(
    {'CarNumber': df4['CarNumber'][:925],
     'NAME': [np.random.choice(surnames) for i in range(925)]}
     )

# %%
digits = list('0123456789')
letters = list('ABCDEFGHIJKLMNOPQRSTUVWXYZ')

# %%
def generate_car_number():
    res = np.random.choice(digits + letters)
    for i in range(3):
        res += np.random.choice(digits)
    for i in range(2):
        res += np.random.choice(digits + letters)
    for i in range(3):
        res += np.random.choice(digits)
    res += 'RUS'
    return res

# %%
data = {'CarNumber': [generate_car_number() for i in range(5)]}
data.update({col: [np.random.choice(df4[col]) for i in range(5)]
             for col in ['Refund', 'Fines', 'Make', 'Model', 'Year']})

df4 = pd.concat([df4, pd.DataFrame(data)])

# %%
owners = owners.drop(owners.tail(20).index)

# %%
data = {'CarNumber': [generate_car_number() for i in range(5)],
        'NAME': [np.random.choice(surnames) for i in range(5)]}

owners = pd.concat([owners, pd.DataFrame(data)])

# %%
pd.pivot_table(df4, values='Fines', index=['Make', 'Model'], columns=['Year'],
               aggfunc=np.sum)
# Out:
# Year                         1980     1981           1982          1983  \
# Make       Model
# Audi                          NaN      NaN            NaN           NaN
# BMW                   3000.000000      NaN            NaN           NaN
# Ford       Focus    173089.172932  68300.0  142594.586466  40894.586466
#            Golf               NaN      NaN            NaN           NaN
#            Mondeo             NaN      NaN            NaN           NaN
# Skoda      Octavia    6900.000000   4000.0    5200.000000           NaN
# Toyota     Camry      1000.000000      NaN            NaN           NaN
#            Corolla            NaN      NaN   24000.000000           NaN
# Volkswagen                    NaN      NaN    7400.000000           NaN
#            Focus              NaN      NaN            NaN           NaN
#            Golf       4600.000000      NaN   31200.000000  24000.000000
#            Jetta              NaN      NaN            NaN           NaN
# ...

# %%
df4.to_csv('/content/drive/MyDrive/df4.json', orient='records')
owners.to_csv('/content/drive/MyDrive/owners.csv', index=False)
